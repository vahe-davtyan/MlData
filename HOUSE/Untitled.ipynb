# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(df_train.isna().sum()[df_train.isna().sum() != 0].sort_values(), df_train.isna().sum()[df_train.isna().sum() != 0].sort_values() * 100 / len(df_train))
# Out:
# Electrical         1
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageYrBlt       81
# GarageType        81
# LotFrontage      259
# FireplaceQu      690
# MasVnrType       872
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64 Electrical       0.068493
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtFinType1     2.534247
# BsmtExposure     2.602740
# BsmtFinType2     2.602740
# GarageCond       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageYrBlt      5.547945
# GarageType       5.547945
# LotFrontage     17.739726
# FireplaceQu     47.260274
# MasVnrType      59.726027
# Fence           80.753425
# Alley           93.767123
# MiscFeature     96.301370
# PoolQC          99.520548
# dtype: float64

# %%
df_train['PoolQC'].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
df_train = df_train.drop(['Fence', 'Alley', 'MiscFeature', 'PoolQC'], axis=1)

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Electrical        1
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
# BsmtExposure     38
# BsmtFinType2     38
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# LotFrontage     259
# FireplaceQu     690
# MasVnrType      872
# dtype: int64

# %%
df_train['MasVnrType']
# Out:
# 0       BrkFace
# 1           NaN
# 2       BrkFace
# 3           NaN
# 4       BrkFace
#          ...
# 1455        NaN
# 1456      Stone
# 1457        NaN
# 1458        NaN
# 1459        NaN
# Name: MasVnrType, Length: 1460, dtype: object

# %%
df_train['MasVnrType'].unique()
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
df_train['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    1317
# Stone       128
# BrkCmn       15
# Name: count, dtype: int64

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 0        1          60       RL         65.0     8450   Pave      Reg  \
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch
# ...

# %%
df_train[df_train['MasVnrType'].isna()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 1        2          20       RL         80.0     9600   Pave      Reg  \
# 3        4          70       RL         60.0     9550   Pave      IR1
# 5        6          50       RL         85.0    14115   Pave      IR1
# 8        9          50       RM         51.0     6120   Pave      Reg
# 9       10         190       RL         50.0     7420   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  1455          20       FV         62.0     7500   Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch
# ...

# %%
df_train['MasVnrType'] = df_train['MasVnrType'].fillna('BrkFace')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Electrical        1
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
# BsmtExposure     38
# BsmtFinType2     38
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# LotFrontage     259
# FireplaceQu     690
# dtype: int64

# %%
df_train['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df_train['FireplaceQu'] = df_train['FireplaceQu'].fillna('Gd')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Electrical        1
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
# BsmtExposure     38
# BsmtFinType2     38
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# LotFrontage     259
# dtype: int64

# %%
df_test['LotFrontage'] = df_test['LotFrontage'].interpolatepolate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df_test['LotFrontage'] = df_test['LotFrontage'].interpolatepolate()
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'interpolatepolate'

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Electrical       1
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# BsmtExposure    38
# BsmtFinType2    38
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
df_train['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
df_test['Electrical'] = df_test['Electrical'].fillna('')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
df_train['MasVnrArea'] = df_train['MasVnrArea'].interpolate()

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
df_train['BsmtQual'] = df_train['BsmtQual'].fillna('TA')

# %%
df_train['BsmtCond'].value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
df_test['BsmtCond'] = df_test['BsmtCond'].fillna('TA')

# %%
df_test['BsmtFinType1'].value_counts()
# Out:
# BsmtFinType1
# GLQ    431
# Unf    421
# ALQ    209
# Rec    155
# BLQ    121
# LwQ     80
# Name: count, dtype: int64

# %%
df_test['BsmtFinType1'] = df_test['BsmtFinType1'].fillna('Unf')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
df_train['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
df_test['BsmtExposure'] = df_test['BsmtExposure'].fillna('No')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# BsmtFinType2    38
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
df_train['BsmtFinType2'].value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
df_test['BsmtFinType2'] = df_test['BsmtFinType2'].fillna('Unf')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
df_train['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
df_test['GarageType'] = df_test['GarageType'].fillna('Attchd')

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()
# Out:
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
df_test['GarageYrBlt'] = df_test['GarageYrBlt'].interpolate()

# %%
df_test['GarageFinish'] = df_test['GarageFinish'].fillna('Unf')

# %%
df_test['GarageQual'] = df_test['GarageQual'].fillna('TA')

# %%
df_test['GarageCond'] = df_test['GarageCond'].fillna('TA')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 0        1          60       RL         65.0     8450   Pave      Reg  \
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch
# ...

# %%
df_train = pd.get_dummies(df_train)

# %%
df_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond
# 0        1          60         65.0     8450            7            5  \
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw
# ...

# %%
df_test = df_test.drop('Id', axis=1)

# %%
X_train = df_train.drop('SalePrice', axis=1)
y_train = df_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
model = LinearRegression()
scaler = StandardScaler()
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
df_test = pd.get_dummies(df_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\User\Desktop\ML_FUL\venv\lib\site-packages\sklearn\utils\multiclass.py:380: RuntimeWarning: invalid value encountered in cast
#   if xp.any(data != data.astype(int)):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 print(classification_report(y_test, y_pred))
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\sklearn\metrics\_classification.py:2310, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2195 def classification_report(
#    2196     y_true,
#    2197     y_pred,
#    (...)
#    2204     zero_division="warn",
#    2205 ):
#    2206     """Build a text report showing the main classification metrics.
#    2207
#    2208     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2307     <BLANKLINE>
#    2308     """
# ...

# %%
y_pred = pipe.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 y_pred = pipe.predict(df_test)
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\sklearn\pipeline.py:480, in Pipeline.predict(self, X, **predict_params)
#     478 Xt = X
#     479 for _, name, transform in self._iter(with_final=False):
# --> 480     Xt = transform.transform(Xt)
#     481 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
# ...

# %%
df_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt
# 0             60         65.0     8450            7            5       2003  \
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
df_test
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt
# 0             20         80.0    11622            5            6       1961  \
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
pipe.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 pipe.predict(df_test)
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\sklearn\pipeline.py:480, in Pipeline.predict(self, X, **predict_params)
#     478 Xt = X
#     479 for _, name, transform in self._iter(with_final=False):
# --> 480     Xt = transform.transform(Xt)
#     481 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~\Desktop\ML_FUL\venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
# ...

# %%
df_test.isna().sum()[df_test.isna().sum() != 0].sort_values()
# Out:
# MasVnrArea    15
# BsmtQual      44
# dtype: int64

# %%
df_test['BsmtUnfSF'] = df_test['BsmtUnfSF'].interpolate()

# %%
df_test['GarageCars'] =df_test['GarageCars'].interpolate()

# %%
df_test['KitchenQual'] = df_test['KitchenQual'].fillna('TA')

# %%
df_test['Exterior1st'] = df_test['Exterior1st'].fillna('CemntBd')

# %%
df_test['Exterior2nd'] = df_test['Exterior2nd'].fillna('CmentBd')

# %%
df_test['GarageArea'] = df_test['GarageArea'].interpolate()

# %%
df_test['SaleType'] = df_test['SaleType'].fillna('WD')

# %%
df_test['Utilities'] = df_test['Utilities'].fillna('AllPub')

# %%
df_test['BsmtFullBath'] = df_test['BsmtFullBath'].interpolate()

# %%
df_test['BsmtHalfBath'] = df_test['BsmtHalfBath'].interpolate()

# %%
df_test['Functional'] = df_test['Functional'].fillna('Typ')

# %%
df_test['MSZoning'] = df_test['MSZoning'].fillna('RL')

# %%
df_test = df_test.drop(['Fence', 'Alley', 'MiscFeature', 'PoolQC'], axis=1)

# %%
df_test['BsmtFinSF1']
# Out:
# 0        468.0
# 1        923.0
# 2        791.0
# 3        602.0
# 4        263.0
#          ...
# 1454       0.0
# 1455     252.0
# 1456    1224.0
# 1457     337.0
# 1458     758.0
# Name: BsmtFinSF1, Length: 1459, dtype: float64

# %%
df_test['TotalBsmtSF'] = df_test['TotalBsmtSF'].interpolate()

# %%
df_test['MasVnrArea'] = df_test['MasVnrArea'].interpolate()

# %%
df_test['BsmtFinSF2'] = df_test['BsmtFinSF2'].interpolate()

# %%
df_test.isna().sum()[df_test.isna().sum() != 0].sort_values()
# Out:
# BsmtUnfSF         1
# GarageArea        1
# GarageCars        1
# KitchenQual       1
# TotalBsmtSF       1
# BsmtFinSF2        1
# BsmtFinSF1        1
# SaleType          1
# Exterior2nd       1
# Exterior1st       1
# BsmtFullBath      2
# BsmtHalfBath      2
# Functional        2
# Utilities         2
# MSZoning          4
# MasVnrArea       15
# BsmtQual         44
# GarageQual       78
# LotFrontage     227
# dtype: int64

# %%
df_test['FireplaceQu'] = df_test['FireplaceQu'].fillna('Gd')

# %%
df_test['Electrical'] = df_test['Electrical'].fillna('SBrkr')

# %%
df_test['MasVnrType'] = df_test['MasVnrType'].fillna('BrkFace')

# %%
df_test['BsmtQual'] = df_test['BsmtQual'].fillna('TA')

# %%
df_test.isna().sum()[df_test.isna().sum() != 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 0     1461          20       RH         80.0    11622   Pave      Reg  \
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch
# ...

# %%
df_test['LotFrontage'] = df_test['LotFrontage'].fillna(50)

# %%
y_pred = pipe.predict(df_test)

# %%
df_test
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt
# 0             20         80.0    11622            5            6       1961  \
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
new_df_train = df_train.copy()
new_df_test = df_test.copy()

# %%
x_new = new_df_train.drop('SalePrice', axis=1)

# %%
y_new = new_df_train['SalePrice']

# %%
x_new = np.sum(new_df_train, axis=1)

# %%
x_new = pd.DataFrame(data=x_new, columns=['Train'])

# %%
x_new
# Out:
#          Train
# 0     231100.0
# 1     205015.0
# 2     249191.0
# 3     163534.0
# 4     280646.0
# ...        ...
# 1455  196819.0
# 1456  239503.0
# 1457  293451.0
# 1458  164931.0
# 1459  171609.0
#
# [1460 rows x 1 columns]

# %%
y_new
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_new, y_new, test_size=0.32, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
model =LinearRegression()
scaler = StandardScaler()
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
new_test = df_test.copy()
new_test = np.sum(new_test, axis=1)

# %%
new_test = pd.DataFrame(data=new_test, columns=['Train'])

# %%
y_t_pred = pipe.predict(new_test)

# %%
sub = pd.read_csv('sample_submission.csv')

# %%
sub['SalePrice'] = y_t_pred

# %%
sub.to_csv('ttt.csv', index=False, index_label=False)
